# %% [markdown]
# **Reading the table of July-2018, 2020, 2022 with selected columns**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# Didn't merge any tables of different years 
air_2018_df = pd.read_csv('./07-2018 Airport.csv')
air_2020_df = pd.read_csv('./07-2020 Airport.csv')
air_2022_df = pd.read_csv('./07-2022 Airport.csv')

air_2018_df.head(10)
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK                FL_DATE  \
# 0  2018        3      7             1            7   7/1/2018 12:00:00 AM
# 1  2018        3      7             2            1   7/2/2018 12:00:00 AM
# 2  2018        3      7             3            2   7/3/2018 12:00:00 AM
# 3  2018        3      7             4            3   7/4/2018 12:00:00 AM
# 4  2018        3      7             5            4   7/5/2018 12:00:00 AM
# 5  2018        3      7             6            5   7/6/2018 12:00:00 AM
# 6  2018        3      7             7            6   7/7/2018 12:00:00 AM
# 7  2018        3      7             8            7   7/8/2018 12:00:00 AM
# 8  2018        3      7             9            1   7/9/2018 12:00:00 AM
# 9  2018        3      7            10            2  7/10/2018 12:00:00 AM
#
#    OP_CARRIER_AIRLINE_ID  ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID  ...  \
# 0                  20409              12478    JFK            11697  ...
# ...

# %%
air_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501590 entries, 0 to 501589
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   YEAR                   501590 non-null  int64
#  1   QUARTER                501590 non-null  int64
#  2   MONTH                  501590 non-null  int64
#  3   DAY_OF_MONTH           501590 non-null  int64
#  4   DAY_OF_WEEK            501590 non-null  int64
#  5   FL_DATE                501590 non-null  object
#  6   OP_CARRIER_AIRLINE_ID  501590 non-null  int64
#  7   ORIGIN_AIRPORT_ID      501590 non-null  int64
#  8   ORIGIN                 501590 non-null  object
#  9   DEST_AIRPORT_ID        501590 non-null  int64
#  10  DEST                   501590 non-null  object
#  11  CRS_DEP_TIME           501590 non-null  int64
#  12  DEP_TIME               494496 non-null  float64
#  13  DEP_DELAY              494471 non-null  float64
# ...

# %% [markdown]
# **Exploring cancelled airlines or airports**

# %%
# if variable 'cancelled' == 1, then it's cancelled. 
cancelled_2018 = air_2018_df[air_2018_df['CANCELLED']==1]
cancelled_2018
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 24      2018        3      7            25            3
# 88      2018        3      7            27            5
# 208     2018        3      7            23            1
# 280     2018        3      7             2            1
# 295     2018        3      7            17            2
# ...      ...      ...    ...           ...          ...
# 501031  2018        3      7            24            2
# 501136  2018        3      7            24            2
# 501217  2018        3      7            24            2
# 501242  2018        3      7            24            2
# 501316  2018        3      7            24            2
#
#                       FL_DATE  OP_CARRIER_AIRLINE_ID  ORIGIN_AIRPORT_ID  \
# 24      7/25/2018 12:00:00 AM                  20409              12478
# 88      7/27/2018 12:00:00 AM                  20409              12889
# 208     7/23/2018 12:00:00 AM                  20409              14771
# ...

# %%
'''
Variable 'CANCELLATION_CODE'
A: Carrier
B: Weather
C: National Air System
D: Security

cc_a = cancelled airline due to carrier (A)..
'''
cc_a_2018 = cancelled_2018[cancelled_2018['CANCELLATION_CODE']=='A']
cc_b_2018 = cancelled_2018[cancelled_2018['CANCELLATION_CODE']=='B']
cc_c_2018 = cancelled_2018[cancelled_2018['CANCELLATION_CODE']=='C']
cc_d_2018 = cancelled_2018[cancelled_2018['CANCELLATION_CODE']=='D']

# %%
# counting occasions by the cancellation_code
print(len(cc_a_2018))
print(len(cc_b_2018))
print(len(cc_c_2018))
print(len(cc_d_2018))
# Out:
# 2788
# 2554
# 2088
# 0

# %%
# 2020 cancellation
cancelled_2020 = air_2020_df[air_2020_df['CANCELLED']==1]

cc_a_2020 = cancelled_2020[cancelled_2020['CANCELLATION_CODE']=='A']
cc_b_2020 = cancelled_2020[cancelled_2020['CANCELLATION_CODE']=='B']
cc_c_2020 = cancelled_2020[cancelled_2020['CANCELLATION_CODE']=='C']
cc_d_2020 = cancelled_2020[cancelled_2020['CANCELLATION_CODE']=='D']

print(len(cc_a_2020))
print(len(cc_b_2020))
print(len(cc_c_2020))
print(len(cc_d_2020))
# Out:
# 1249
# 500
# 23
# 1041

# %%
# 2022 cancellation
cancelled_2022 = air_2022_df[air_2022_df['CANCELLED']==1]

cc_a_2022 = cancelled_2022[cancelled_2022['CANCELLATION_CODE']=='A']
cc_b_2022 = cancelled_2022[cancelled_2022['CANCELLATION_CODE']=='B']
cc_c_2022 = cancelled_2022[cancelled_2022['CANCELLATION_CODE']=='C']
cc_d_2022 = cancelled_2022[cancelled_2022['CANCELLATION_CODE']=='D']

print(len(cc_a_2022))
print(len(cc_b_2022))
print(len(cc_c_2022))
print(len(cc_d_2022))
# Out:
# 4488
# 4206
# 1783
# 69

# %% [markdown]
# **Exploring delays**

# %%
'''
CarrierDelay
Carrier Delay, in Minutes

WeatherDelay
Weather Delay, in Minutes

NASDelay
National Air System Delay, in Minutes

SecurityDelay
Security Delay, in Minutes

LateAircraftDelay
Late Aircraft Delay, in Minutes

da_c = delayed airline due to carrier..
'''

da_c_2018 = air_2018_df[air_2018_df['CARRIER_DELAY']==1]
da_w_2018 = air_2018_df[air_2018_df['WEATHER_DELAY']==1]
da_n_2018 = air_2018_df[air_2018_df['NAS_DELAY']==1]
da_s_2018 = air_2018_df[air_2018_df['SECURITY_DELAY']==1]
da_l_2018 = air_2018_df[air_2018_df['LATE_AIRCRAFT_DELAY']==1]

# %%
# counting occasions by the cause of delay
print(len(da_c_2018))
print(len(da_w_2018))
print(len(da_n_2018))
print(len(da_s_2018))
print(len(da_l_2018))
# Out:
# 2210
# 112
# 2790
# 13
# 1039

# %%
# 2020 Delays
da_c_2020 = air_2020_df[air_2020_df['CARRIER_DELAY']==1]
da_w_2020 = air_2020_df[air_2020_df['WEATHER_DELAY']==1]
da_n_2020 = air_2020_df[air_2020_df['NAS_DELAY']==1]
da_s_2020 = air_2020_df[air_2020_df['SECURITY_DELAY']==1]
da_l_2020 = air_2020_df[air_2020_df['LATE_AIRCRAFT_DELAY']==1]
print(len(da_c_2020))
print(len(da_w_2020))
print(len(da_n_2020))
print(len(da_s_2020))
print(len(da_l_2020))
# Out:
# 249
# 32
# 568
# 0
# 118

# %%
# 2022 Delays
da_c_2022 = air_2022_df[air_2022_df['CARRIER_DELAY']==1]
da_w_2022 = air_2022_df[air_2022_df['WEATHER_DELAY']==1]
da_n_2022 = air_2022_df[air_2022_df['NAS_DELAY']==1]
da_s_2022 = air_2022_df[air_2022_df['SECURITY_DELAY']==1]
da_l_2022 = air_2022_df[air_2022_df['LATE_AIRCRAFT_DELAY']==1]
print(len(da_c_2022))
print(len(da_w_2022))
print(len(da_n_2022))
print(len(da_s_2022))
print(len(da_l_2022))
# Out:
# 2557
# 109
# 3293
# 16
# 921

# %%
### Cancellation
# A	Carrier
# B	Weather
# C	National Air System
# D	Security

# %%
print(air_2018_df['CANCELLATION_CODE'].unique())
print(air_2020_df['CANCELLATION_CODE'].unique())
print(air_2022_df['CANCELLATION_CODE'].unique())
# Out:
# [nan 'A' 'B' 'C']
# [nan 'D' 'B' 'A' 'C']
# [nan 'A' 'B' 'C' 'D']

# %%
types_cancel_18 = air_2018_df['CANCELLATION_CODE'].value_counts()
print('2018')
print(types_cancel_18.to_dict())
print('Remainder, without cancellation: ' + str(len(air_2018_df)-types_cancel_18.sum()))
air_2018_df.groupby(['CANCELLED','CANCELLATION_CODE']).size().reset_index()
# Out:
# 2018
# {'A': 2788, 'B': 2554, 'C': 2088}
# Remainder, without cancellation: 494160
#    CANCELLED CANCELLATION_CODE     0
# 0        1.0                 A  2788
# 1        1.0                 B  2554
# 2        1.0                 C  2088

# %%
print('2020')
types_cancel_20 = air_2020_df['CANCELLATION_CODE'].value_counts()
print(types_cancel_20.to_dict())
print('Remainder, without cancellation: ' + str(len(air_2020_df)-types_cancel_20.sum()))
air_2020_df.groupby(['CANCELLED','CANCELLATION_CODE']).size().reset_index()
# Out:
# 2020
# {'A': 1249, 'D': 1041, 'B': 500, 'C': 23}
# Remainder, without cancellation: 350075
#    CANCELLED CANCELLATION_CODE     0
# 0        1.0                 A  1249
# 1        1.0                 B   500
# 2        1.0                 C    23
# 3        1.0                 D  1041

# %%
print('2022')
types_cancel_22 = air_2022_df['CANCELLATION_CODE'].value_counts()
print(types_cancel_22.to_dict())
print('Remainder, without cancellation: ' + str(len(air_2022_df)-types_cancel_22.sum()))
air_2022_df.groupby(['CANCELLED','CANCELLATION_CODE']).size().reset_index()
# Out:
# 2022
# {'A': 4488, 'B': 4206, 'C': 1783, 'D': 69}
# Remainder, without cancellation: 584411
#    CANCELLED CANCELLATION_CODE     0
# 0        1.0                 A  4488
# 1        1.0                 B  4206
# 2        1.0                 C  1783
# 3        1.0                 D    69

# %%
air_2018_df.nunique()
# Out:
# YEAR                        1
# QUARTER                     1
# MONTH                       1
# DAY_OF_MONTH               31
# DAY_OF_WEEK                 7
# FL_DATE                    31
# OP_CARRIER_AIRLINE_ID      14
# ORIGIN_AIRPORT_ID         286
# ORIGIN                    286
# DEST_AIRPORT_ID           286
# DEST                      286
# CRS_DEP_TIME             1211
# DEP_TIME                 1433
# DEP_DELAY                 861
# CRS_ARR_TIME             1303
# ARR_TIME                 1440
# ARR_DELAY                 879
# CANCELLED                   2
# CANCELLATION_CODE           3
# CARRIER_DELAY             664
# WEATHER_DELAY             377
# NAS_DELAY                 443
# SECURITY_DELAY             81
# LATE_AIRCRAFT_DELAY       506
# dtype: int64

# %%
groupby_18 = air_2018_df.groupby(['DEP_DELAY','CANCELLED','CANCELLATION_CODE']).size().reset_index()
groupby_18[groupby_18['CANCELLED']==1]
# Out:
#      DEP_DELAY  CANCELLED CANCELLATION_CODE  0
# 0        -14.0        1.0                 A  1
# 1        -12.0        1.0                 B  1
# 2        -11.0        1.0                 B  2
# 3        -10.0        1.0                 A  1
# 4         -9.0        1.0                 B  1
# ..         ...        ...               ... ..
# 210      432.0        1.0                 A  1
# 211      447.0        1.0                 C  1
# 212      470.0        1.0                 A  1
# 213      507.0        1.0                 A  1
# 214      774.0        1.0                 A  1
#
# [215 rows x 4 columns]

# %%
groupby_18[groupby_18['CANCELLED']==1][0].sum()
# Out:
# 312

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.hist(air_2018_df[air_2018_df['CANCELLED']==1]['DEP_DELAY'])
ax2.hist(air_2018_df[air_2018_df['CANCELLED']==0]['DEP_DELAY'])
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.hist(air_2020_df[air_2020_df['CANCELLED']==1]['DEP_DELAY'])
ax2.hist(air_2020_df[air_2020_df['CANCELLED']==0]['DEP_DELAY'])
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.hist(air_2022_df[air_2022_df['CANCELLED']==1]['DEP_DELAY'])
ax2.hist(air_2022_df[air_2022_df['CANCELLED']==0]['DEP_DELAY'])
fig.show()

# %%
len(air_2018_df[air_2018_df['CANCELLED']==1])/len(air_2018_df)
# Out:
# 0.014812894993919336

# %%
len(air_2020_df[air_2020_df['CANCELLED']==1])/len(air_2020_df)
# Out:
# 0.0079713676860647

# %%
len(air_2022_df[air_2022_df['CANCELLED']==1])/len(air_2022_df)
# Out:
# 0.017725650761315524
